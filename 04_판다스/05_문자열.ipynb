# %%
import pandas as pd

data = {
    "A" : ["데이터 분석", "기본 학습서", "퇴근 후 열공"], 
    "B" : [10, 20, 30], 
    "C" : ["ab cd", "AB CD", "ab cd "]
}

df = pd.DataFrame(data)
df
# Out:
#          A   B       C
# 0   데이터 분석  10   ab cd
# 1   기본 학습서  20   AB CD
# 2  퇴근 후 열공  30  ab cd

# %%
df["A"] = df["A"].str.replace("분석", "시각화")
df
# Out:
#          A   B       C
# 0  데이터 시각화  10   ab cd
# 1   기본 학습서  20   AB CD
# 2  퇴근 후 열공  30  ab cd

# %%
df["A"] = df["A"].replace("기본 학습서", "데이터 분석")
df
# Out:
#          A   B       C
# 0  데이터 시각화  10   ab cd
# 1   데이터 분석  20   AB CD
# 2  퇴근 후 열공  30  ab cd

# %%
df["A"] = df["A"].replace("분석", "시각화")
df
# Out:
#          A   B       C
# 0  데이터 시각화  10   ab cd
# 1   데이터 분석  20   AB CD
# 2  퇴근 후 열공  30  ab cd

# %%
df["A"] = df["A"].str.replace("분석", "시각화")
df
# Out:
#          A   B       C
# 0  데이터 시각화  10   ab cd
# 1  데이터 시각화  20   AB CD
# 2  퇴근 후 열공  30  ab cd

# %%
df["B"] = df["B"].replace(10, 100)
df
# Out:
#          A    B       C
# 0  데이터 시각화  100   ab cd
# 1  데이터 시각화   20   AB CD
# 2  퇴근 후 열공   30  ab cd

# %%
# 문자열 분리
df["A"].str.split(" ")
# Out:
# 0     [데이터, 시각화]
# 1     [데이터, 시각화]
# 2    [퇴근, 후, 열공]
# Name: A, dtype: object

# %%
df["A"].str.split(" ")[0]
# Out:
# ['데이터', '시각화']

# %%
df["D"] = df["A"].str.split(" ").str[0]
df
# Out:
#          A    B       C    D
# 0  데이터 시각화  100   ab cd  데이터
# 1  데이터 시각화   20   AB CD  데이터
# 2  퇴근 후 열공   30  ab cd    퇴근

# %%
# 특정 문자열 검색 
df["시각화 포함여부"] = df["A"].str.contains("시각화")
df
# Out:
#          A    B       C    D  시각화 포함여부
# 0  데이터 시각화  100   ab cd  데이터      True
# 1  데이터 시각화   20   AB CD  데이터      True
# 2  퇴근 후 열공   30  ab cd    퇴근     False

# %%
# 문자열 길이
df["문자길이"] = df["A"].str.len()
df
# Out:
#          A    B       C    D  시각화 포함여부  문자길이
# 0  데이터 시각화  100   ab cd  데이터      True     7
# 1  데이터 시각화   20   AB CD  데이터      True     7
# 2  퇴근 후 열공   30  ab cd    퇴근     False     7

# %%
# 문자열 대(소)문자 변경
"ab cd" == "AB CD"
# Out:
# False

# %%
df["C"] = df["C"].str.lower()
df
# Out:
#          A    B       C    D  시각화 포함여부  문자길이
# 0  데이터 시각화  100   ab cd  데이터      True     7
# 1  데이터 시각화   20   ab cd  데이터      True     7
# 2  퇴근 후 열공   30  ab cd    퇴근     False     7

# %%
# 대문자로 변경
df["C"] = df["C"].str.upper()
df
# Out:
#          A    B       C    D  시각화 포함여부  문자길이
# 0  데이터 시각화  100   AB CD  데이터      True     7
# 1  데이터 시각화   20   AB CD  데이터      True     7
# 2  퇴근 후 열공   30  AB CD    퇴근     False     7

# %%
df["C"] == "AB CD"
# Out:
# 0     True
# 1     True
# 2    False
# Name: C, dtype: bool

# %%
# 공백 제거 
df["C"] = df["C"].str.replace(" ", "")
df["C"] = df["C"].str.lower()

# %%
df
# Out:
#          A    B     C    D  시각화 포함여부  문자길이
# 0  데이터 시각화  100  abcd  데이터      True     7
# 1  데이터 시각화   20  abcd  데이터      True     7
# 2  퇴근 후 열공   30  abcd   퇴근     False     7

# %%
df["CD"] =df["C"].str[2:4]
df
# Out:
#          A    B     C    D  시각화 포함여부  문자길이  CD
# 0  데이터 시각화  100  abcd  데이터      True     7  cd
# 1  데이터 시각화   20  abcd  데이터      True     7  cd
# 2  퇴근 후 열공   30  abcd   퇴근     False     7  cd
