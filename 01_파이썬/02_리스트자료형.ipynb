# %%
odd = [1, 3, 5, 7, 9]

a = []
b = ["life", "is", "too", "short"]
c = [1, 2, "life", "is"] 
d = [1, 2, ["life", "is"]]

# %%
a = [1, 2, 3, ["a", "b", "c"]]
a[0]
a[3][1]
# Out:
# 'b'

# %%
a[3]
# Out:
# ['a', 'b', 'c']

# %%
a[-1]
# Out:
# ['a', 'b', 'c']

# %%
a = [1, 2, ["a", "b", ["life", "is"]]]
a[-1][-1][-1]
# Out:
# 'is'

# %%
a = [1, 2, 3, 4, 5]
a[0:2]
a[2:4]
# Out:
# [3, 4]

# %%
a[0:4]
a[:4]
# Out:
# [1, 2, 3, 4]

# %%
a[1:5]
a[1:]
a[:]
# Out:
# [1, 2, 3, 4, 5]

# %%
# 리스트더하기 
a = [1, 2, 3]
b = [4, 5, 6]

a + b
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# 리스트 곱하기(*)
a = [1, 2, 3] 
a * 3
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]

# %%
# 리스트 길이를 구하는 함수 
a = [1, 2, 3]
len(a)
# Out:
# 3

# %%
# 리스트 값을 수정하기 

a = [1, 2, 3]
a[2] = 4

a
# Out:
# [1, 2, 4]

# %%
# a[3] = 5 
# 리스트 범위를 벗어남

a.append(5)
a
# Out:
# [1, 2, 4, 5]

# %%
a = sorted(a, reverse=True)
a
# Out:
# [5, 4, 2, 1]

# %%
a.sort()
a.reverse()
a
# Out:
# [5, 4, 2, 1]

# %%
a.index(4)
a.index(1)
# Out:
# 3

# %%
a.insert(2, 3)
a
# Out:
# [5, 4, 3, 2, 1]

# %%
# 리스트 요소 제거하기 - remove 
a.remove(1)
a
# Out:
# [5, 4, 3, 2]

# %%
# 리스트 요소 끄집어내기 - pop
a = [5, 4, 3, 2, 1]
result = a.pop()
print(result)
print(a)
# Out:
# 1
# [5, 4, 3, 2]

# %%
a = [5, 4, 3, 2, 1]
result = a.pop(2)
print(result)
# Out:
# 3

# %%
a
# Out:
# [5, 4, 2, 1]

# %%
# 리스트확장 - extend 

a = [1, 2, 3]
a.extend([4, 5])
a
# Out:
# [1, 2, 3, 4, 5, 4, 5]
