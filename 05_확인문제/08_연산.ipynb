# %%
import pandas as pd 
df = pd.read_csv("type1_data1.csv")

# 1. 모든 나이(age)에 1을 더하시오. 
# 2. 20대의 "views" 평균과 30대의 "views" 평균의 차이의 절대값을 구하시오.
# (반올림 후 소수 둘째 자리까지 계산)

# %%
df.head(3)
df["age"].describe()
# Out:
# count    120.000000
# mean      46.727500
# std       29.520826
# min      -13.500000
# 25%       22.000000
# 50%       42.000000
# 75%       74.250000
# max      100.000000
# Name: age, dtype: float64

# %%
df["age"]=df["age"]+1
df["age"]
# Out:
# 0       3.0
# 1      10.0
# 2      28.0
# 3      76.0
# 4      25.0
#        ...
# 115    23.0
# 116    24.0
# 117    24.0
# 118    24.0
# 119    25.0
# Name: age, Length: 120, dtype: float64

# %%
dd = (df["age"] >= 20) & (df["age"] < 30)
ee = (df["age"] >= 30) & (df["age"] <=40)

dd-ee
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 4
#       1 dd = (df["age"] >= 20) & (df["age"] < 30)
#       2 ee = (df["age"] >= 30) & (df["age"] <=40)
# ----> 4 dd-ee
#
# File c:\Users\krcea\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File c:\Users\krcea\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\arraylike.py:194, in OpsMixin.__sub__(self, other)
#     192 @unpack_zerodim_and_defer("__sub__")
#     193 def __sub__(self, other):
# --> 194     return self._arith_method(other, operator.sub)
#
# ...
